# %%
import numpy as np
import pandas as pd

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df=pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#             Opening  Opening.1                     Title  \
# 0     J A N U A R Y        7.0                   The 355
# 1     J A N U A R Y        7.0  The Legend of La Llorona
# 2     J A N U A R Y        7.0              The Commando
# 3     J A N U A R Y        7.0            American Siege
# 4     J A N U A R Y       14.0                    Scream
# ..              ...        ...                       ...
# 86  D E C E M B E R       30.0            Alice, Darling
# 87  D E C E M B E R        NaN                       NaN
# 88  D E C E M B E R        NaN                       NaN
# 89  D E C E M B E R        NaN                       NaN
# 90  D E C E M B E R        NaN                       NaN
#
#                                    Production company  \
# 0   Universal Pictures / Freckle Films / FilmNatio...
# 1                      Saban Films / Ageless Pictures
# 2                Saban Films / Premiere Entertainment
# 3                              Vertical Entertainment
# 4   Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                ...
# 86                     Lionsgate / Elevation Pictures
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 86  Mary Nighy (director); Alanna Francis (screenp...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#      Ref.
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 86  [261]
# 87    NaN
# 88    NaN
# 89    NaN
# 90    NaN
#
# [317 rows x 7 columns]

# %%
pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.2.2)

# %%
#get your API Key here: https://www.themoviedb.org/settings/api
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'f48af0548b24b372079a408ba14ed6fa' #add your own API key here

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    if len(result['results'])==0:
       return np.NaN

    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#             Opening  Opening.1                     Title  \
# 0     J A N U A R Y        7.0                   The 355
# 1     J A N U A R Y        7.0  The Legend of La Llorona
# 2     J A N U A R Y        7.0              The Commando
# 3     J A N U A R Y        7.0            American Siege
# 4     J A N U A R Y       14.0                    Scream
# ..              ...        ...                       ...
# 86  D E C E M B E R       30.0            Alice, Darling
# 87  D E C E M B E R        NaN                       NaN
# 88  D E C E M B E R        NaN                       NaN
# 89  D E C E M B E R        NaN                       NaN
# 90  D E C E M B E R        NaN                       NaN
#
#                                    Production company  \
# 0   Universal Pictures / Freckle Films / FilmNatio...
# 1                      Saban Films / Ageless Pictures
# 2                Saban Films / Premiere Entertainment
# 3                              Vertical Entertainment
# 4   Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                ...
# 86                     Lionsgate / Elevation Pictures
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 86  Mary Nighy (director); Alanna Francis (screenp...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#      Ref.                           genres
# 0     NaN                  Action Thriller
# 1     NaN  Family Animation Fantasy Horror
# 2     NaN            Action Crime Thriller
# 3     NaN        Action Adventure Thriller
# 4     NaN             Crime Horror Mystery
# ..    ...                              ...
# 86  [261]           Thriller Drama Romance
# 87    NaN                      Drama Crime
# 88    NaN                      Drama Crime
# 89    NaN                      Drama Crime
# 90    NaN                      Drama Crime
#
# [317 rows x 8 columns]

# %%
df_2022 = df[['Title','Cast and crew','genres']]
df_2022
# Out:
#                                            Title  \
# 0                                        The 355
# 1                       The Legend of La Llorona
# 2                                   The Commando
# 3                                 American Siege
# 4                                         Scream
# ..                                           ...
# 82  Whitney Houston: I Wanna Dance with Somebody
# 83                             The Pale Blue Eye
# 84                                 Women Talking
# 85                             A Man Called Otto
# 86                                Alice, Darling
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 82  Kasi Lemmons (director); Anthony McCarten (scr...
# 83  Scott Cooper (director/screenplay); Christian ...
# 84  Sarah Polley (director/screenplay); Rooney Mar...
# 85  Marc Forster (director), David Magee (screenpl...
# 86  Mary Nighy (director); Alanna Francis (screenp...
#
#                              genres
# 0                   Action Thriller
# 1   Family Animation Fantasy Horror
# 2             Action Crime Thriller
# 3         Action Adventure Thriller
# 4              Crime Horror Mystery
# ..                              ...
# 82              Music History Drama
# 83    Thriller Crime Horror Mystery
# 84                      Drama Crime
# 85                     Comedy Drama
# 86           Thriller Drama Romance
#
# [313 rows x 3 columns]

# %%
df_2022.dropna(subset=['Title'], inplace=True)

# %%
df_2022
# Out:
#                                            Title  \
# 0                                        The 355
# 1                       The Legend of La Llorona
# 2                                   The Commando
# 3                                 American Siege
# 4                                         Scream
# ..                                           ...
# 82  Whitney Houston: I Wanna Dance with Somebody
# 83                             The Pale Blue Eye
# 84                                 Women Talking
# 85                             A Man Called Otto
# 86                                Alice, Darling
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 82  Kasi Lemmons (director); Anthony McCarten (scr...
# 83  Scott Cooper (director/screenplay); Christian ...
# 84  Sarah Polley (director/screenplay); Rooney Mar...
# 85  Marc Forster (director), David Magee (screenpl...
# 86  Mary Nighy (director); Alanna Francis (screenp...
#
#                              genres
# 0                   Action Thriller
# 1   Family Animation Fantasy Horror
# 2             Action Crime Thriller
# 3         Action Adventure Thriller
# 4              Crime Horror Mystery
# ..                              ...
# 82              Music History Drama
# 83    Thriller Crime Horror Mystery
# 84                      Drama Crime
# 85                     Comedy Drama
# 86           Thriller Drama Romance
#
# [313 rows x 3 columns]

# %%
def get_director(x):
    x=str(x)
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
#let's apply the above function on the "Cast and crew" column
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-73-9fbe60f0042d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2022
# Out:
#                                            Title  \
# 0                                        The 355
# 1                       The Legend of La Llorona
# 2                                   The Commando
# 3                                 American Siege
# 4                                         Scream
# ..                                           ...
# 82  Whitney Houston: I Wanna Dance with Somebody
# 83                             The Pale Blue Eye
# 84                                 Women Talking
# 85                             A Man Called Otto
# 86                                Alice, Darling
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 82  Kasi Lemmons (director); Anthony McCarten (scr...
# 83  Scott Cooper (director/screenplay); Christian ...
# 84  Sarah Polley (director/screenplay); Rooney Mar...
# 85  Marc Forster (director), David Magee (screenpl...
# 86  Mary Nighy (director); Alanna Francis (screenp...
#
#                              genres                         director_name
# 0                   Action Thriller                         Simon Kinberg
# 1   Family Animation Fantasy Horror                Patricia Harris Seeley
# 2             Action Crime Thriller                            Asif Akbar
# 3         Action Adventure Thriller                     Edward John Drake
# 4              Crime Horror Mystery  Matt Bettinelli-Olpin, Tyler Gillett
# ..                              ...                                   ...
# 82              Music History Drama                          Kasi Lemmons
# 83    Thriller Crime Horror Mystery                          Scott Cooper
# 84                      Drama Crime                          Sarah Polley
# 85                     Comedy Drama                          Marc Forster
# 86           Thriller Drama Romance                            Mary Nighy
#
# [313 rows x 4 columns]

# %%
def get_actor1(x):
    x=str(x)
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-75-ba75f0a668e6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2022
# Out:
#                                            Title  \
# 0                                        The 355
# 1                       The Legend of La Llorona
# 2                                   The Commando
# 3                                 American Siege
# 4                                         Scream
# ..                                           ...
# 82  Whitney Houston: I Wanna Dance with Somebody
# 83                             The Pale Blue Eye
# 84                                 Women Talking
# 85                             A Man Called Otto
# 86                                Alice, Darling
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 82  Kasi Lemmons (director); Anthony McCarten (scr...
# 83  Scott Cooper (director/screenplay); Christian ...
# 84  Sarah Polley (director/screenplay); Rooney Mar...
# 85  Marc Forster (director), David Magee (screenpl...
# 86  Mary Nighy (director); Alanna Francis (screenp...
#
#                              genres                         director_name  \
# 0                   Action Thriller                         Simon Kinberg
# 1   Family Animation Fantasy Horror                Patricia Harris Seeley
# 2             Action Crime Thriller                            Asif Akbar
# 3         Action Adventure Thriller                     Edward John Drake
# 4              Crime Horror Mystery  Matt Bettinelli-Olpin, Tyler Gillett
# ..                              ...                                   ...
# 82              Music History Drama                          Kasi Lemmons
# 83    Thriller Crime Horror Mystery                          Scott Cooper
# 84                      Drama Crime                          Sarah Polley
# 85                     Comedy Drama                          Marc Forster
# 86           Thriller Drama Romance                            Mary Nighy
#
#          actor_1_name
# 0    Jessica Chastain
# 1       Autumn Reeser
# 2       Mickey Rourke
# 3   Timothy V. Murphy
# 4     Melissa Barrera
# ..                ...
# 82        Naomi Ackie
# 83     Christian Bale
# 84        Rooney Mara
# 85          Tom Hanks
# 86      Anna Kendrick
#
# [313 rows x 5 columns]

# %%
def get_actor2(x):
    x=str(x)
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-79-da18e330aae0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    x=str(x)
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-81-dff1896922fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2022
# Out:
#                                            Title  \
# 0                                        The 355
# 1                       The Legend of La Llorona
# 2                                   The Commando
# 3                                 American Siege
# 4                                         Scream
# ..                                           ...
# 82  Whitney Houston: I Wanna Dance with Somebody
# 83                             The Pale Blue Eye
# 84                                 Women Talking
# 85                             A Man Called Otto
# 86                                Alice, Darling
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 82  Kasi Lemmons (director); Anthony McCarten (scr...
# 83  Scott Cooper (director/screenplay); Christian ...
# 84  Sarah Polley (director/screenplay); Rooney Mar...
# 85  Marc Forster (director), David Magee (screenpl...
# 86  Mary Nighy (director); Alanna Francis (screenp...
#
#                              genres                         director_name  \
# 0                   Action Thriller                         Simon Kinberg
# 1   Family Animation Fantasy Horror                Patricia Harris Seeley
# 2             Action Crime Thriller                            Asif Akbar
# 3         Action Adventure Thriller                     Edward John Drake
# 4              Crime Horror Mystery  Matt Bettinelli-Olpin, Tyler Gillett
# ..                              ...                                   ...
# 82              Music History Drama                          Kasi Lemmons
# 83    Thriller Crime Horror Mystery                          Scott Cooper
# 84                      Drama Crime                          Sarah Polley
# 85                     Comedy Drama                          Marc Forster
# 86           Thriller Drama Romance                            Mary Nighy
#
#          actor_1_name       actor_2_name      actor_3_name
# 0    Jessica Chastain      Penélope Cruz      Fan Bingbing
# 1       Autumn Reeser        Danny Trejo      Antonio Cupo
# 2       Mickey Rourke  Michael Jai White               NaN
# 3   Timothy V. Murphy       Bruce Willis         Rob Gough
# 4     Melissa Barrera      Mason Gooding      Jenna Ortega
# ..                ...                ...               ...
# 82        Naomi Ackie      Stanley Tucci    Ashton Sanders
# 83     Christian Bale      Harry Melling  Gillian Anderson
# 84        Rooney Mara         Claire Foy    Jessie Buckley
# 85          Tom Hanks    Mariana Treviño     Rachel Keller
# 86      Anna Kendrick    Kaniehtiio Horn   Charlie Carrick
#
# [313 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                            director_name       actor_1_name  \
# 0                          Simon Kinberg   Jessica Chastain
# 1                 Patricia Harris Seeley      Autumn Reeser
# 2                             Asif Akbar      Mickey Rourke
# 3                      Edward John Drake  Timothy V. Murphy
# 4   Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                   ...                ...
# 82                          Kasi Lemmons        Naomi Ackie
# 83                          Scott Cooper     Christian Bale
# 84                          Sarah Polley        Rooney Mara
# 85                          Marc Forster          Tom Hanks
# 86                            Mary Nighy      Anna Kendrick
#
#          actor_2_name      actor_3_name                           genres  \
# 0       Penélope Cruz      Fan Bingbing                  Action Thriller
# 1         Danny Trejo      Antonio Cupo  Family Animation Fantasy Horror
# 2   Michael Jai White               NaN            Action Crime Thriller
# 3        Bruce Willis         Rob Gough        Action Adventure Thriller
# 4       Mason Gooding      Jenna Ortega             Crime Horror Mystery
# ..                ...               ...                              ...
# 82      Stanley Tucci    Ashton Sanders              Music History Drama
# 83      Harry Melling  Gillian Anderson    Thriller Crime Horror Mystery
# 84         Claire Foy    Jessie Buckley                      Drama Crime
# 85    Mariana Treviño     Rachel Keller                     Comedy Drama
# 86    Kaniehtiio Horn   Charlie Carrick           Thriller Drama Romance
#
#                                      movie_title
# 0                                        The 355
# 1                       The Legend of La Llorona
# 2                                   The Commando
# 3                                 American Siege
# 4                                         Scream
# ..                                           ...
# 82  Whitney Houston: I Wanna Dance with Somebody
# 83                             The Pale Blue Eye
# 84                                 Women Talking
# 85                             A Man Called Otto
# 86                                Alice, Darling
#
# [313 rows x 6 columns]

# %%
new_df22['actor_2_name'] = new_df22['actor_2_name'].replace(np.nan, 'unknown')
new_df22['actor_3_name'] = new_df22['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']
new_df22
# Out:
#                            director_name       actor_1_name  \
# 0                          Simon Kinberg   Jessica Chastain
# 1                 Patricia Harris Seeley      Autumn Reeser
# 2                             Asif Akbar      Mickey Rourke
# 3                      Edward John Drake  Timothy V. Murphy
# 4   Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                   ...                ...
# 82                          Kasi Lemmons        Naomi Ackie
# 83                          Scott Cooper     Christian Bale
# 84                          Sarah Polley        Rooney Mara
# 85                          Marc Forster          Tom Hanks
# 86                            Mary Nighy      Anna Kendrick
#
#          actor_2_name      actor_3_name                           genres  \
# 0       Penélope Cruz      Fan Bingbing                  Action Thriller
# 1         Danny Trejo      Antonio Cupo  Family Animation Fantasy Horror
# 2   Michael Jai White           unknown            Action Crime Thriller
# 3        Bruce Willis         Rob Gough        Action Adventure Thriller
# 4       Mason Gooding      Jenna Ortega             Crime Horror Mystery
# ..                ...               ...                              ...
# 82      Stanley Tucci    Ashton Sanders              Music History Drama
# 83      Harry Melling  Gillian Anderson    Thriller Crime Horror Mystery
# 84         Claire Foy    Jessie Buckley                      Drama Crime
# 85    Mariana Treviño     Rachel Keller                     Comedy Drama
# 86    Kaniehtiio Horn   Charlie Carrick           Thriller Drama Romance
#
#                                      movie_title  \
# 0                                        the 355
# 1                       the legend of la llorona
# 2                                   the commando
# 3                                 american siege
# 4                                         scream
# ..                                           ...
# 82  whitney houston: i wanna dance with somebody
# 83                             the pale blue eye
# 84                                 women talking
# 85                             a man called otto
# 86                                alice, darling
#
#                                                  comb
# 0   Jessica Chastain Penélope Cruz Fan Bingbing Si...
# 1   Autumn Reeser Danny Trejo Antonio Cupo Patrici...
# 2   Mickey Rourke Michael Jai White unknown Asif A...
# 3   Timothy V. Murphy Bruce Willis Rob Gough Edwar...
# 4   Melissa Barrera Mason Gooding Jenna Ortega Mat...
# ..                                                ...
# 82  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 83  Christian Bale Harry Melling Gillian Anderson ...
# 84  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 85  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 86  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [313 rows x 7 columns]

# %%
new_df22.to_csv('data_22.csv',index=False)
