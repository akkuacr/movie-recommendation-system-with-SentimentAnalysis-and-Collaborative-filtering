# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
 df=pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#             Opening  Opening.1                    Title  \
# 0     J A N U A R Y          5  Insidious: The Last Key
# 1     J A N U A R Y          5         The Strange Ones
# 2     J A N U A R Y         12             The Commuter
# 3     J A N U A R Y         12               Proud Mary
# 4     J A N U A R Y         12         Acts of Violence
# ..              ...        ...                      ...
# 56  D E C E M B E R         21               Second Act
# 57  D E C E M B E R         25          Holmes & Watson
# 58  D E C E M B E R         25                     Vice
# 59  D E C E M B E R         25      On the Basis of Sex
# 60  D E C E M B E R         25                Destroyer
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2       Lionsgate / StudioCanal / The Picture Company
# 3                                         Screen Gems
# 4                                  Lionsgate Premiere
# ..                                                ...
# 56                                  STX Entertainment
# 57  Columbia Pictures / Gary Sanchez Productions /...
# 58          Annapurna Pictures / Plan B Entertainment
# 59                                     Focus Features
# 60                                 Annapurna Pictures
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Christopher Radcliff (director/screenplay); La...
# 2   Jaume Collet-Serra (director); Byron Willinger...
# 3   Babak Najafi (director); John S. Newman, Chris...
# 4   Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                ...
# 56  Peter Segal (director); Justin Zackham, Elaine...
# 57  Etan Cohen (director/screenplay); Will Ferrell...
# 58  Adam McKay (director/screenplay); Christian Ba...
# 59  Mimi Leder (director); Daniel Stiepleman (scre...
# 60  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
#      Ref.
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 56  [236]
# 57  [142]
# 58  [117]
# 59  [207]
# 60  [237]
#
# [247 rows x 7 columns]

# %%
pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.2.2)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %%
#get your API Key here: https://www.themoviedb.org/settings/api
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'f48af0548b24b372079a408ba14ed6fa' #add your own API key here

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#             Opening  Opening.1                    Title  \
# 0     J A N U A R Y          5  Insidious: The Last Key
# 1     J A N U A R Y          5         The Strange Ones
# 2     J A N U A R Y         12             The Commuter
# 3     J A N U A R Y         12               Proud Mary
# 4     J A N U A R Y         12         Acts of Violence
# ..              ...        ...                      ...
# 56  D E C E M B E R         21               Second Act
# 57  D E C E M B E R         25          Holmes & Watson
# 58  D E C E M B E R         25                     Vice
# 59  D E C E M B E R         25      On the Basis of Sex
# 60  D E C E M B E R         25                Destroyer
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2       Lionsgate / StudioCanal / The Picture Company
# 3                                         Screen Gems
# 4                                  Lionsgate Premiere
# ..                                                ...
# 56                                  STX Entertainment
# 57  Columbia Pictures / Gary Sanchez Productions /...
# 58          Annapurna Pictures / Plan B Entertainment
# 59                                     Focus Features
# 60                                 Annapurna Pictures
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Christopher Radcliff (director/screenplay); La...
# 2   Jaume Collet-Serra (director); Byron Willinger...
# 3   Babak Najafi (director); John S. Newman, Chris...
# 4   Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                ...
# 56  Peter Segal (director); Justin Zackham, Elaine...
# 57  Etan Cohen (director/screenplay); Will Ferrell...
# 58  Adam McKay (director/screenplay); Christian Ba...
# 59  Mimi Leder (director); Daniel Stiepleman (scre...
# 60  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
#      Ref.                          genres
# 0     NaN         Horror Mystery Thriller
# 1     NaN                   Drama Mystery
# 2     NaN         Action Thriller Mystery
# 3     NaN           Thriller Action Crime
# 4     NaN           Action Crime Thriller
# ..    ...                             ...
# 56  [236]                  Romance Comedy
# 57  [142]  Mystery Adventure Comedy Crime
# 58  [117]                    Comedy Drama
# 59  [207]                   Drama History
# 60  [237]     Thriller Crime Drama Action
#
# [247 rows x 8 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                       Title  \
# 0   Insidious: The Last Key
# 1          The Strange Ones
# 2              The Commuter
# 3                Proud Mary
# 4          Acts of Violence
# ..                      ...
# 56               Second Act
# 57          Holmes & Watson
# 58                     Vice
# 59      On the Basis of Sex
# 60                Destroyer
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Christopher Radcliff (director/screenplay); La...
# 2   Jaume Collet-Serra (director); Byron Willinger...
# 3   Babak Najafi (director); John S. Newman, Chris...
# 4   Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                ...
# 56  Peter Segal (director); Justin Zackham, Elaine...
# 57  Etan Cohen (director/screenplay); Will Ferrell...
# 58  Adam McKay (director/screenplay); Christian Ba...
# 59  Mimi Leder (director); Daniel Stiepleman (scre...
# 60  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                             genres
# 0          Horror Mystery Thriller
# 1                    Drama Mystery
# 2          Action Thriller Mystery
# 3            Thriller Action Crime
# 4            Action Crime Thriller
# ..                             ...
# 56                  Romance Comedy
# 57  Mystery Adventure Comedy Crime
# 58                    Comedy Drama
# 59                   Drama History
# 60     Thriller Crime Drama Action
#
# [247 rows x 3 columns]

# %% [markdown]
# Extracting directors

# %%
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
#let's apply the above function on the "Cast and crew" column
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-14-e4fd6ee00db5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %% [markdown]
# **Extracting Actor1 , Actor2, Actor3**

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))


def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
df_2018
# Out:
# <ipython-input-15-a67e18e5e1eb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# <ipython-input-15-a67e18e5e1eb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# <ipython-input-15-a67e18e5e1eb>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
#                       Title  \
# 0   Insidious: The Last Key
# 1          The Strange Ones
# 2              The Commuter
# 3                Proud Mary
# 4          Acts of Violence
# ..                      ...
# 56               Second Act
# 57          Holmes & Watson
# 58                     Vice
# 59      On the Basis of Sex
# 60                Destroyer
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Christopher Radcliff (director/screenplay); La...
# 2   Jaume Collet-Serra (director); Byron Willinger...
# 3   Babak Najafi (director); John S. Newman, Chris...
# 4   Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                ...
# 56  Peter Segal (director); Justin Zackham, Elaine...
# 57  Etan Cohen (director/screenplay); Will Ferrell...
# 58  Adam McKay (director/screenplay); Christian Ba...
# 59  Mimi Leder (director); Daniel Stiepleman (scre...
# 60  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                             genres  \
# 0          Horror Mystery Thriller
# 1                    Drama Mystery
# 2          Action Thriller Mystery
# 3            Thriller Action Crime
# 4            Action Crime Thriller
# ..                             ...
# 56                  Romance Comedy
# 57  Mystery Adventure Comedy Crime
# 58                    Comedy Drama
# 59                   Drama History
# 60     Thriller Crime Drama Action
#
#                                         director_name  \
# 0                                        Adam Robitel
# 1   Christopher Radcliff (director/screenplay); La...
# 2                                  Jaume Collet-Serra
# 3                                        Babak Najafi
# 4                                       Brett Donowho
# ..                                                ...
# 56                                        Peter Segal
# 57                                         Etan Cohen
# 58                                         Adam McKay
# 59                                         Mimi Leder
# 60                                       Karyn Kusama
#
#                                   actor_1_name            actor_2_name  \
# 0                                    Lin Shaye           Angus Sampson
# 1   Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                  Liam Neeson            Vera Farmiga
# 3                             Taraji P. Henson    Jahi Di'Allo Winston
# 4                                 Bruce Willis             Cole Hauser
# ..                                         ...                     ...
# 56                              Jennifer Lopez             Leah Remini
# 57                                Will Ferrell          John C. Reilly
# 58                              Christian Bale               Amy Adams
# 59                              Felicity Jones            Armie Hammer
# 60                               Nicole Kidman          Sebastian Stan
#
#        actor_3_name
# 0    Leigh Whannell
# 1     Emily Althaus
# 2    Patrick Wilson
# 3       Billy Brown
# 4     Shawn Ashmore
# ..              ...
# 56  Vanessa Hudgens
# 57     Rebecca Hall
# 58     Steve Carell
# 59   Justin Theroux
# 60     Toby Kebbell
#
# [247 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                         director_name  \
# 0                                        Adam Robitel
# 1   Christopher Radcliff (director/screenplay); La...
# 2                                  Jaume Collet-Serra
# 3                                        Babak Najafi
# 4                                       Brett Donowho
# ..                                                ...
# 56                                        Peter Segal
# 57                                         Etan Cohen
# 58                                         Adam McKay
# 59                                         Mimi Leder
# 60                                       Karyn Kusama
#
#                                   actor_1_name            actor_2_name  \
# 0                                    Lin Shaye           Angus Sampson
# 1   Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                  Liam Neeson            Vera Farmiga
# 3                             Taraji P. Henson    Jahi Di'Allo Winston
# 4                                 Bruce Willis             Cole Hauser
# ..                                         ...                     ...
# 56                              Jennifer Lopez             Leah Remini
# 57                                Will Ferrell          John C. Reilly
# 58                              Christian Bale               Amy Adams
# 59                              Felicity Jones            Armie Hammer
# 60                               Nicole Kidman          Sebastian Stan
#
#        actor_3_name                          genres              movie_title
# 0    Leigh Whannell         Horror Mystery Thriller  Insidious: The Last Key
# 1     Emily Althaus                   Drama Mystery         The Strange Ones
# 2    Patrick Wilson         Action Thriller Mystery             The Commuter
# 3       Billy Brown           Thriller Action Crime               Proud Mary
# 4     Shawn Ashmore           Action Crime Thriller         Acts of Violence
# ..              ...                             ...                      ...
# 56  Vanessa Hudgens                  Romance Comedy               Second Act
# 57     Rebecca Hall  Mystery Adventure Comedy Crime          Holmes & Watson
# 58     Steve Carell                    Comedy Drama                     Vice
# 59   Justin Theroux                   Drama History      On the Basis of Sex
# 60     Toby Kebbell     Thriller Crime Drama Action                Destroyer
#
# [247 rows x 6 columns]

# %% [markdown]
# Replacing Null values from actor names

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18
# Out:
#                                         director_name  \
# 0                                        Adam Robitel
# 1   Christopher Radcliff (director/screenplay); La...
# 2                                  Jaume Collet-Serra
# 3                                        Babak Najafi
# 4                                       Brett Donowho
# ..                                                ...
# 56                                        Peter Segal
# 57                                         Etan Cohen
# 58                                         Adam McKay
# 59                                         Mimi Leder
# 60                                       Karyn Kusama
#
#                                   actor_1_name            actor_2_name  \
# 0                                    Lin Shaye           Angus Sampson
# 1   Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                  Liam Neeson            Vera Farmiga
# 3                             Taraji P. Henson    Jahi Di'Allo Winston
# 4                                 Bruce Willis             Cole Hauser
# ..                                         ...                     ...
# 56                              Jennifer Lopez             Leah Remini
# 57                                Will Ferrell          John C. Reilly
# 58                              Christian Bale               Amy Adams
# 59                              Felicity Jones            Armie Hammer
# 60                               Nicole Kidman          Sebastian Stan
#
#        actor_3_name                          genres              movie_title  \
# 0    Leigh Whannell         Horror Mystery Thriller  insidious: the last key
# 1     Emily Althaus                   Drama Mystery         the strange ones
# 2    Patrick Wilson         Action Thriller Mystery             the commuter
# 3       Billy Brown           Thriller Action Crime               proud mary
# 4     Shawn Ashmore           Action Crime Thriller         acts of violence
# ..              ...                             ...                      ...
# 56  Vanessa Hudgens                  Romance Comedy               second act
# 57     Rebecca Hall  Mystery Adventure Comedy Crime          holmes & watson
# 58     Steve Carell                    Comedy Drama                     vice
# 59   Justin Theroux                   Drama History      on the basis of sex
# 60     Toby Kebbell     Thriller Crime Drama Action                destroyer
#
#                                                  comb
# 0   Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1   Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2   Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3   Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4   Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                ...
# 56  Jennifer Lopez Leah Remini Vanessa Hudgens Pet...
# 57  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 58  Christian Bale Amy Adams Steve Carell Adam McK...
# 59  Felicity Jones Armie Hammer Justin Theroux Mim...
# 60  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
#
# [247 rows x 7 columns]

# %% [markdown]
# **Extracting Features for 2019 Movies**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
 df=pd.concat([df1,df2,df3,df4])
 df
# Out:
#             Opening  Opening.1              Title  \
# 0     J A N U A R Y          4        Escape Room
# 1     J A N U A R Y          4         Rust Creek
# 2     J A N U A R Y          4   American Hangman
# 3     J A N U A R Y         11   A Dog's Way Home
# 4     J A N U A R Y         11         The Upside
# ..              ...        ...                ...
# 66  D E C E M B E R         25  Spies in Disguise
# 67  D E C E M B E R         25       Little Women
# 68  D E C E M B E R         25               1917
# 69  D E C E M B E R         25         Just Mercy
# 70  D E C E M B E R         27           Clemency
#
#                                    Production company  \
# 0                   Columbia Pictures / Original Film
# 1                      IFC Films / Lunacy Productions
# 2                         Hangman Justice Productions
# 3                                   Columbia Pictures
# 4                                   STX Entertainment
# ..                                                ...
# 66  20th Century Fox / Blue Sky Studios / Chernin ...
# 67            Columbia Pictures / Regency Enterprises
# 68           Universal Pictures / DreamWorks Pictures
# 69          Warner Bros. Pictures / Participant Media
# 70                                               Neon
#
#                                         Cast and crew   Ref.
# 0   Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1   Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2   Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3   Charles Martin Smith (director); W. Bruce Came...    [5]
# 4   Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                ...    ...
# 66  Nick Bruno, Troy Quane (directors); Brad Copel...  [130]
# 67  Greta Gerwig (director/screenplay); Saoirse Ro...  [223]
# 68  Sam Mendes (director/screenplay); Krysty Wilso...  [224]
# 69  Destin Daniel Cretton (director/screenplay), A...  [225]
# 70  Chinonye Chukwu (director/screenplay); Alfre W...  [226]
#
# [247 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#             Opening  Opening.1              Title  \
# 0     J A N U A R Y          4        Escape Room
# 1     J A N U A R Y          4         Rust Creek
# 2     J A N U A R Y          4   American Hangman
# 3     J A N U A R Y         11   A Dog's Way Home
# 4     J A N U A R Y         11         The Upside
# ..              ...        ...                ...
# 66  D E C E M B E R         25  Spies in Disguise
# 67  D E C E M B E R         25       Little Women
# 68  D E C E M B E R         25               1917
# 69  D E C E M B E R         25         Just Mercy
# 70  D E C E M B E R         27           Clemency
#
#                                    Production company  \
# 0                   Columbia Pictures / Original Film
# 1                      IFC Films / Lunacy Productions
# 2                         Hangman Justice Productions
# 3                                   Columbia Pictures
# 4                                   STX Entertainment
# ..                                                ...
# 66  20th Century Fox / Blue Sky Studios / Chernin ...
# 67            Columbia Pictures / Regency Enterprises
# 68           Universal Pictures / DreamWorks Pictures
# 69          Warner Bros. Pictures / Participant Media
# 70                                               Neon
#
#                                         Cast and crew   Ref.  \
# 0   Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1   Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2   Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3   Charles Martin Smith (director); W. Bruce Came...    [5]
# 4   Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                ...    ...
# 66  Nick Bruno, Troy Quane (directors); Brad Copel...  [130]
# 67  Greta Gerwig (director/screenplay); Saoirse Ro...  [223]
# 68  Sam Mendes (director/screenplay); Krysty Wilso...  [224]
# 69  Destin Daniel Cretton (director/screenplay), A...  [225]
# 70  Chinonye Chukwu (director/screenplay); Alfre W...  [226]
#
#                                       genres
# 0                    Horror Thriller Mystery
# 1                Thriller Drama Action Crime
# 2                                   Thriller
# 3                     Drama Adventure Family
# 4                               Comedy Drama
# ..                                       ...
# 66  Animation Action Adventure Comedy Family
# 67                             Drama Romance
# 68                  War Action Drama History
# 69                       Drama Crime History
# 70                                     Drama
#
# [247 rows x 7 columns]

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 66  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 67       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 68               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 69         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 70           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                       genres
# 0                    Horror Thriller Mystery
# 1                Thriller Drama Action Crime
# 2                                   Thriller
# 3                     Drama Adventure Family
# 4                               Comedy Drama
# ..                                       ...
# 66  Animation Action Adventure Comedy Family
# 67                             Drama Romance
# 68                  War Action Drama History
# 69                       Drama Crime History
# 70                                     Drama
#
# [247 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-29-a433a4faa834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-31-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-33-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 66  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 67            Greta Gerwig        Saoirse Ronan           Emma Watson
# 68              Sam Mendes        George MacKay  Dean-Charles Chapman
# 69   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 70         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#         actor_3_name                                    genres  \
# 0   Deborah Ann Woll                   Horror Thriller Mystery
# 1       Sean O'Bryan               Thriller Drama Action Crime
# 2      Oliver Dennis                                  Thriller
# 3    Alexandra Shipp                    Drama Adventure Family
# 4      Nicole Kidman                              Comedy Drama
# ..               ...                                       ...
# 66     Rashida Jones  Animation Action Adventure Comedy Family
# 67     Florence Pugh                             Drama Romance
# 68       Mark Strong                  War Action Drama History
# 69       Brie Larson                       Drama Crime History
# 70       Aldis Hodge                                     Drama
#
#           movie_title                                               comb
# 0         escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1          rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2    american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3    a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4          the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                ...                                                ...
# 66  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 67       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 68               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 69         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 70           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [247 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)
my_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-2593d99052c0> in <cell line: 1>()
# ----> 1 my_df = new_df18.append(new_df19,ignore_index=True)
#       2 my_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
my_df = pd.concat([new_df18, new_df19], ignore_index=True)

# %%
df_18_19=my_df

# %%
df_18_19.to_csv('data_18_19.csv',index=False)

# %%
credits = pd.read_csv('/content/data_18_19.csv')

# %%
credits
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 489                             Nick Bruno, Troy Quane
# 490                                       Greta Gerwig
# 491                                         Sam Mendes
# 492                              Destin Daniel Cretton
# 493                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 489                                  Will Smith             Tom Holland
# 490                               Saoirse Ronan             Emma Watson
# 491                               George MacKay    Dean-Charles Chapman
# 492                           Michael B. Jordan              Jamie Foxx
# 493                               Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                   Horror Mystery Thriller
# 1     Emily Althaus                             Drama Mystery
# 2    Patrick Wilson                   Action Thriller Mystery
# 3       Billy Brown                     Thriller Action Crime
# 4     Shawn Ashmore                     Action Crime Thriller
# ..              ...                                       ...
# 489   Rashida Jones  Animation Action Adventure Comedy Family
# 490   Florence Pugh                             Drama Romance
# 491     Mark Strong                  War Action Drama History
# 492     Brie Larson                       Drama Crime History
# 493     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 489        spies in disguise
# 490             little women
# 491                     1917
# 492               just mercy
# 493                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 489  Will Smith Tom Holland Rashida Jones Nick Brun...
# 490  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 491  George MacKay Dean-Charles Chapman Mark Strong...
# 492  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 493  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [494 rows x 7 columns]
